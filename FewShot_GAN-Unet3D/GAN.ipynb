# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Kursinis/FewShot_GAN-Unet3D/pytorch

# %%
# !pip install tensorboardX

# %%
# !pip install nipype

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/Kursinis/FewShot_GAN-Unet3D/pytorch/main.py" "/content/drive/MyDrive/Colab Notebooks/Kursinis/FewShot_GAN-Unet3D/pytorch/configs/fmgan.json"
# Out:
#  THE Configuration of your experiment ..
# {'agent': 'FMGAN_Model',
#  'async_loading': True,
#  'batch_size': 64,
#  'beta1D': 0.5,
#  'beta1G': 0.5,
#  'beta2D': 0.999,
#  'beta2G': 0.999,
#  'checkpoint_dir': './checkpoints/',
#  'checkpoint_file': 'checkpoint.pth.tar',
#  'cuda': True,
#  'data_directory': './data/dataverse_files',
#  'data_loader_workers': 0,
#  'data_mode': 'imgs',
#  'epochs': 50,
#  'exp_name': 'fmgan_experiment',
#  'extraction_step': [8, 8, 8],
#  'gpu_device': 0,
#  'learning_rate_D': 0.0001,
#  'learning_rate_G': 0.0001,
#  'load_chkpt': True,
#  'noise_dim': 200,
#  'num_classes': 9,
#  'num_modalities': 2,
#  'number_images_training': 3,
#  'number_unlab_images_training': 3,
#  'patch_shape': [16, 16, 16],
#  'phase': 'testing',
#  'pin_memory': False,
#  'relu_slope': 0.2,
#  'seed': 1,
#  'validation_every_epoch': 5,
#  'volume_shape': [144, 192, 256],
#  'weight_decay': 0}
#  ***************************************
# ...
